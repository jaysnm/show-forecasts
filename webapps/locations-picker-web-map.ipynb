# %%
# Application initialization
import mercury as mr

import warnings

warnings.filterwarnings("ignore")

show_code = mr.Checkbox(value=False, label="Show code", url_key="show_code")

app = mr.App(
    title="Locations Picker Web Map",
    description="A web map application for picking locations of interest and exporting to JSON file.",
    show_code=show_code.value,
    allow_download=False,
)
# Out:
# mercury.Checkbox
# mercury.App

# %% [markdown]
# ## Using location picker to extract location coordinates of any place
#
# - Click the marker icon on top-left corner of the map just below the zoom icons
# - After clicking the marker icon below zoom icons, click anywhere on the map to define place of interest
# - Click the marker drawn on the map to show coordinates. The coordinates will be shown as a notification box. If you don't get it, ensure window notifications are enabled on your browser

# %%
import folium
from folium.plugins import Draw

m = folium.Map(
    location=(-0.624251, 38.414451), control_scale=True, width="100%", height="75%"
)

Draw(
    export=True,
    show_geometry_on_click=True,
    filename="draw-marker-coordinates.geojson",
    draw_options={
        "polyline": False,
        "polygon": False,
        "rectangle": False,
        "circle": False,
        "circlemarker": False,
    },
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
